# %% [markdown]
# # Assignment 1 AI
# ## _Sohybe Ibrahim Abdelwahab Amer_
# ## ID: 222250182

# %% [markdown]
# ----------------

# %% [markdown]
# ## LAB 1 AI:

# %%
# Question 1

def prime(n):
    is_prime = False
    if n <= 1:
        print("The number is negative!")
    else:
        is_prime = True
        for i in range(2, int(n**0.5) + 1):
            if n % i == 0:
                is_prime = False
                break
    if is_prime:
        print("The number is prime.")
    else:
        print("The number is not prime.")

# Example of the output:
prime(7)
prime(-2)
prime(9)
prime(10)
# Out:
# The number is prime.
# The number is negative!
# The number is not prime.
# The number is not prime.
# The number is not prime.

# %%
# Question 2:

def sum_digits(number):
    total = 0
    for digit_char in str(number):
        total += int(digit_char)
    return total


# Example of the output:
num = 12345
result = sum_digits(num)

print(f"The number is: {num}")
print(f"The sum of its digits is: {result}")
# Out:
# The number is: 12345
# The sum of its digits is: 15

# %%
# Question 3:

N = int(input("Enter the number N: "))
for i in range(1, N + 1):
    print(f"--- Multiplication Table for {i} ---")
    for j in range(1, 11):
        print(f"{i} x {j} = {i * j}")
    print()
# Out:
# --- Multiplication Table for 1 ---
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
#
# --- Multiplication Table for 2 ---
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
#
# --- Multiplication Table for 3 ---
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
#
# --- Multiplication Table for 4 ---
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
#
# --- Multiplication Table for 5 ---
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
# Question 4

my_list = ['madam', 'hello', 'level', 'world', 'radar']
palindromes = []
non_palindromes = []

for word in my_list:
    if word == word[::-1]:
        palindromes.append(word)
    else:
        non_palindromes.append(word)

print("Palindrome Words:")
for p in palindromes:
    print(p)

print("\nNon Palindrome Words:")
for np in non_palindromes:
    print(f"'{np}'")
# Out:
# Palindrome Words:
# madam
# level
# radar
#
# Non Palindrome Words:
# 'hello'
# 'world'

# %%
# Question 5

sentence = "Hello world, this is a Python program."

word_count = 0
i = 0
in_word = False
length = len(sentence)

while i < length:
    char = sentence[i]
    if not char.isspace():
        if not in_word:
            word_count += 1
            in_word = True
    else:
        in_word = False
    i += 1

print(f"The sentence is: '{sentence}'")
print(f"The number of words is: {word_count}")
# Out:
# The sentence is: 'Hello world, this is a Python program.'
# The number of words is: 7

# %%
# Question 6

num1 = 48
num2 = 18

a = num1
b = num2

while b:
    a, b = b, a % b

gcd = a

print(f"num1 = {num1}")
print(f"num2 = {num2}")
print(f"The GCD of the given numbers is: {gcd}")
# Out:
# num1 = 48
# num2 = 18
# The GCD of the given numbers is: 6

# %%
# Question 7

a = num1
b = num2

while b:
    a, b = b, a % b

gcd = a

lcm = (num1 * num2) // gcd

print(f"num1 = {num1}")
print(f"num2 = {num2}")
print(f"The LCM of {num1} and {num2} is: {lcm}")
# Out:
# num1 = 48
# num2 = 18
# The LCM of 48 and 18 is: 144

# %% [markdown]
# ## Session Tasks in the given Notebook

# %%
# Task 1

try:
    salary_input = input("Please enter your current salary: ")
    salary = float(salary_input)

    raise_amount = salary * 0.20
    new_salary = salary + raise_amount

    print(f"Your current salary is: ${salary:,.2f}")
    print(f"Your 20% raise is: ${raise_amount:,.2f}")
    print(f"Your new salary will be: ${new_salary:,.2f}")

except ValueError:
    print("Invalid input. Please enter a valid number for your salary.")
# Out:
# Your current salary is: $2,500.00
# Your 20% raise is: $500.00
# Your new salary will be: $3,000.00

# %%
# Task 2

try:
    num1 = float(input("Enter the first number: "))
    operator = input("Enter an operator (+, -, *, /): ")
    num2 = float(input("Enter the second number: "))

    result = 0

    if operator == '+':
        result = num1 + num2
    elif operator == '-':
        result = num1 - num2
    elif operator == '*':
        result = num1 * num2
    elif operator == '/':
        if num2 == 0:
            print("Error: Cannot divide by zero.")
            result = "undefined"
        else:
            result = num1 / num2
    else:
        print("Error: Invalid operator entered.")
        result = "invalid"

    if result != "undefined" and result != "invalid":
        print(f"The result of {num1} {operator} {num2} is: {result}")

except ValueError:
    print("Invalid input. Please enter valid numbers.")
# Out:
# The result of 3.0 + 33.0 is: 36.0

# %%
# Task 3

try:
    num_students = int(input("Enter the number of students: "))

    if num_students <= 0:
        print("Please enter a positive number of students.")
    else:
        scores = []
        for i in range(num_students):
            while True:
                try:
                    score = float(input(f"Enter score for student {i + 1}: "))
                    scores.append(score)
                    break
                except ValueError:
                    print("Invalid score. Please enter a number.")

        average_grade = sum(scores) / len(scores)

        print(f"\nAll scores: {scores}")
        print(f"Average grade: {average_grade:.2f}")

        if average_grade >= 60:
            print("Result: pass")
        else:
            print("Result: fail")

except ValueError:
    print("Invalid input. Please enter a valid integer for the number of students.")
# Out:
# All scores: [90.0, 86.0, 70.0, 78.0, 95.0]
# Average grade: 83.80
# Result: pass
